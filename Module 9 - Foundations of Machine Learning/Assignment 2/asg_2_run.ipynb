# %%
from assignment_2_final import *
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.width', None)

# %%
lambda_values = [0.0, 0.25, 0.5, 0.75, 1.0]

run_task6(lambda_values, epochs=5)
# Out:
# Training Item Classification Model...
# Epoch 1/5
#   74/1200 ━━━━━━━━━━━━━━━━━━━━ 52s 47ms/step - accuracy: 0.4928 - loss: 1.2889
# 2025-03-02 18:18:28.892176: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: INVALID_ARGUMENT: Incompatible shapes: [3,3,64,128] vs. [0]
# 	 [[{{function_node __inference_one_step_on_data_2700}}{{node adam/Mul_19}}]]
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[2], line 3
#       1 lambda_values = [0.0, 0.25, 0.5, 0.75, 1.0]
# ----> 3 run_task6(lambda_values, epochs=5)
#
# File ~/Projects/MSc-AI/Module 9 - Foundations of Machine Learning/Assignment 2/assignment_2_final.py:1351, in run_task6(lambda_values, epochs, batch_size)
#    1347 def run_task6(lambda_values, epochs, batch_size=50):
#    1349     train_X, train_y_1, train_y_2, test_X, test_y_1, test_y_2 = load_fashion_mnist_data()
# -> 1351     single_results = train_single_task_models(
#    1352         train_X, train_y_1, train_y_2,
#    1353         test_X, test_y_1, test_y_2,
#    1354         batch_size=batch_size,
#    1355         epochs=epochs
#    1356     )
#    1358     mtl_results = train_multitask_models(
#    1359         train_X, train_y_1, train_y_2,
#    1360         test_X, test_y_1, test_y_2,
#    (...)
#    1363         epochs=epochs
#    1364     )
#    1366     analyse_results(single_results, mtl_results, lambda_values)
#
# File ~/Projects/MSc-AI/Module 9 - Foundations of Machine Learning/Assignment 2/assignment_2_final.py:1177, in train_single_task_models(train_X, train_y_1, train_y_2, test_X, test_y_1, test_y_2, batch_size, epochs)
#    1175 print("\nTraining Item Classification Model...")
#    1176 start_time = time.time()
# -> 1177 history_task1 = model_task1.fit(train_X, train_y_1, batch_size=batch_size, epochs=epochs, validation_data=(test_X, test_y_1), verbose=1)
#    1178 task1_train_time = time.time() - start_time
#    1179 task1_test_loss, task1_test_acc = model_task1.evaluate(test_X, test_y_1, verbose=0)
#
# File ~/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node adam/Mul_19 defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#
#   File "/opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#
#   File "/opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/events.py", line 88, in _run
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#
#   File "/var/folders/r9/lmtf195n4jj9qjmbr834vmrm0000gn/T/ipykernel_10931/2856366194.py", line 3, in <module>
#
#   File "/Users/leon/Projects/MSc-AI/Module 9 - Foundations of Machine Learning/Assignment 2/assignment_2_final.py", line 1351, in run_task6
#
#   File "/Users/leon/Projects/MSc-AI/Module 9 - Foundations of Machine Learning/Assignment 2/assignment_2_final.py", line 1177, in train_single_task_models
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 371, in fit
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 219, in function
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 132, in multi_step_on_iterator
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 113, in one_step_on_data
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 80, in train_step
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py", line 383, in apply_gradients
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py", line 448, in apply
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py", line 511, in _backend_apply_gradients
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/keras/src/backend/tensorflow/optimizer.py", line 120, in _backend_update_step
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/keras/src/backend/tensorflow/optimizer.py", line 134, in _distributed_tf_update_step
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/keras/src/backend/tensorflow/optimizer.py", line 131, in apply_grad_to_update_var
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/keras/src/optimizers/adam.py", line 148, in update_step
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/keras/src/ops/numpy.py", line 6016, in multiply
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/keras/src/backend/tensorflow/sparse.py", line 627, in sparse_wrapper
#
#   File "/Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/keras/src/backend/tensorflow/numpy.py", line 523, in multiply
#
# Incompatible shapes: [3,3,64,128] vs. [0]
# 	 [[{{node adam/Mul_19}}]] [Op:__inference_multi_step_on_iterator_2801]
