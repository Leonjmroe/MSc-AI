# %%
from assignment_2_final import *

# %%
digit_paris = [(1, 0), (8, 3), (4, 9)]

run_task1(digit_paris)

# %%
digit_pairs = [(1, 0), (8, 3), (4, 9), (8, 7), (2, 9)]

run_task2(digit_pairs)
# Out:
# Loaded MNIST: X_train=(60000, 784), X_test=(10000, 784)
#
# --- Perceptron for digit pair 1 vs 0 ---
#   Training Accuracy: 0.9990
#   Test Accuracy: 0.9991
# --- Perceptron for digit pair 8 vs 3 ---
#   Training Accuracy: 0.9724
#   Test Accuracy: 0.9662
# --- Perceptron for digit pair 4 vs 9 ---
#   Training Accuracy: 0.9690
#   Test Accuracy: 0.9689
# --- Perceptron for digit pair 8 vs 7 ---
#   Training Accuracy: 0.9942
#   Test Accuracy: 0.9900
# --- Perceptron for digit pair 2 vs 9 ---
#   Training Accuracy: 0.9902
#   Test Accuracy: 0.9829
# ----- Perceptron Results -----
#   Digit Pair  Train Accuracy  Test Accuracy  Iterations
# 0     1_vs_0          0.9990       0.999054         335
# 1     8_vs_3          0.9724       0.966230        1000
# 2     4_vs_9          0.9690       0.968860        1000
# 3     8_vs_7          0.9942       0.990010        1000
# 4     2_vs_9          0.9902       0.982852        1000
#   Digit Pair  Train Accuracy  Test Accuracy  Iterations
# ...

# %%
mlp_architectures = {
          'MLP-2': [1000, 1000],
          'MLP-3': [800, 800, 800],
          'MLP-4': [700, 700, 700, 700],
          'MLP-5': [600, 600, 600, 600, 600],
          'MLP-6': [500, 500, 500, 500, 500, 500]
      }

run_task3(mlp_architectures, epochs=5)
# Out:
# MNIST loaded: X_train=(60000, 784), X_test=(10000, 784)
#
# --- Training MLP [1000,1000] ---
# Epoch 1/5
# /Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7362 - loss: 0.9119 - val_accuracy: 0.9136 - val_loss: 0.2658
# Epoch 2/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9232 - loss: 0.2446 - val_accuracy: 0.9224 - val_loss: 0.2375
# Epoch 3/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9407 - loss: 0.1769 - val_accuracy: 0.9429 - val_loss: 0.1813
# Epoch 4/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9537 - loss: 0.1288 - val_accuracy: 0.9319 - val_loss: 0.2321
# Epoch 5/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9581 - loss: 0.1206 - val_accuracy: 0.9216 - val_loss: 0.2664
# ...

# %%
cnn_architectures = {
        'CNN-2': [64, 128],
        'CNN-3': [32, 64, 128],
        'CNN-4': [32, 64, 96, 128],
        'CNN-5': [32, 48, 64, 96, 128],
        'CNN-6': [16, 32, 48, 64, 96, 128]
    }

run_task4(cnn_architectures=cnn_architectures, epochs=5)
# Out:
# --- Base CNN Model ---
# /Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_21 (Conv2D)              │ (None, 28, 28, 32)     │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 14, 14, 64)     │        32,832 │
# ...

# %%
digit_pairs=[(2, 9)]

run_task5(digit_pairs, epochs=3)
# Out:
# Creating and training a simple CNN model...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 digit_pairs=[(2, 9)]
# ----> 3 run_task5(digit_pairs, epochs=3)
#
# File ~/Projects/MSc-AI/Module 9 - Foundations of Machine Learning/Assignment 2/assignment_2_final.py:1279, in run_task5(digit_pairs, epochs, cols, batch_size)
#    1276 y_test = keras.utils.to_categorical(y_test_original, 10)
#    1278 print("Creating and training a simple CNN model...")
# -> 1279 model = create_cnn()
#    1281 # Build the model explicitly with the input shape
#    1282 model.build((None, 28, 28, 1))
#
# TypeError: create_cnn() missing 3 required positional arguments: 'input_shape', 'filters', and 'output_units'

# %%
lambda_values = lambda_values=[0.0, 0.25, 0.5, 0.75, 1.0]

run_task6(lambda_values, epochs=5)
# Out:
# Parameters: batch_size=50, epochs=5, lambda_values=[0.0, 0.25, 0.5, 0.75, 1.0]
# Data loaded: train_X shape=(60000, 28, 28, 1), test_X shape=(10000, 28, 28, 1)
# Item Classification - Model Summary:
# /Users/leon/Library/Caches/pypoetry/virtualenvs/msc-ai-yPHgmFUp-py3.12/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "Single_Task1_Item"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           320 │
# ...
